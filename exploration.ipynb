# %%
import pandas as pd
import numpy as np

# %%
car_data = pd.read_csv("data.csv")

# %%
car_data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
car_data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
# %pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: pandas>=1.2 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /mnt/ianch-Secondary/Programming/linux_venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
target = "MSRP"

# %%
car_data["Age"] = car_data["Year"].max() - car_data["Year"]
base = ["Age", "Engine HP", "Engine Cylinders", "Number of Doors", "highway MPG", "city mpg", "Popularity"]

# %%
car_data['Transmission Type'].value_counts()
# Out:
# Transmission Type
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: count, dtype: int64

# %%
for v in ['AUTOMATIC', 'MANUAL', 'AUTOMATED_MANUAL']:
    feature = f"is_transmission_{v}"
    car_data[feature] = (car_data['Transmission Type'] == v).astype(int)
    base.append(feature)

# %%
base.append(target)

# %%
car_data[base].sample(3)
# Out:
#        Age  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# 698      7      631.0              12.0              4.0           16
# 10520    9      185.0               6.0              4.0           24
# 7005    11      200.0               6.0              4.0           23
#
#        city mpg  Popularity  is_transmission_AUTOMATIC  \
# 698          10          67                          1
# 10520        17         210                          1
# 7005         16         586                          1
#
#        is_transmission_MANUAL  is_transmission_AUTOMATED_MANUAL    MSRP
# 698                         0                                 0  506500
# 10520                       0                                 0   23520
# 7005                        0                                 0   28515

# %%
price_mean = np.mean(car_data[target])
np.log1p(price_mean)
# Out:
# np.float64(10.611418340866752)

# %%
sns.histplot(car_data[target])
# Out:
# <Axes: xlabel='MSRP', ylabel='Count'>

# %%
# log plot
sns.histplot(np.log1p(car_data[target]))
# Out:
# <Axes: xlabel='MSRP', ylabel='Count'>

# %%
data = car_data[base]
data.head()
# Out:
#    Age  Engine HP  Engine Cylinders  Number of Doors  highway MPG  city mpg  \
# 0    6      335.0               6.0              2.0           26        19
# 1    6      300.0               6.0              2.0           28        19
# 2    6      300.0               6.0              2.0           28        20
# 3    6      230.0               6.0              2.0           28        18
# 4    6      230.0               6.0              2.0           28        18
#
#    Popularity  is_transmission_AUTOMATIC  is_transmission_MANUAL  \
# 0        3916                          0                       1
# 1        3916                          0                       1
# 2        3916                          0                       1
# 3        3916                          0                       1
# 4        3916                          0                       1
#
#    is_transmission_AUTOMATED_MANUAL   MSRP
# 0                                 0  46135
# 1                                 0  40650
# 2                                 0  36350
# 3                                 0  29450
# 4                                 0  34500

# %%
np.random.seed(123)
n = len(data)
idx = np.arange(n)
np.random.shuffle(idx)
data_shuffled = data.iloc[idx]

# %%
n_test = int(0.2*n)
n_val = int(0.2*n)
n_train = n - (n_val+n_test)
n_test, n_val, n_train
# Out:
# (2382, 2382, 7150)

# %%
train_data = data_shuffled[:n_train]
val_data = data_shuffled[n_train:n_train+n_val]
test_data = data_shuffled[n_train+n_val:]

# %%
x_train = train_data.drop(columns=["MSRP"])
y_train = train_data["MSRP"]
x_val = val_data.drop(columns=["MSRP"])
y_val = val_data["MSRP"]
x_test = test_data.drop(columns=["MSRP"])
y_test = test_data["MSRP"]

# %%
x_train.head()
# Out:
#        Age  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# 2839    23      113.0               4.0              4.0           30
# 7553     3      453.0              12.0              2.0           19
# 10214    0      278.0               6.0              4.0           23
# 7614     1      280.0               6.0              4.0           27
# 7789     1      300.0               6.0              4.0           29
#
#        city mpg  Popularity  is_transmission_AUTOMATIC  \
# 2839         23         535                          0
# 7553         11          86                          1
# 10214        18        2031                          1
# 7614         19        2202                          1
# 7789         19         190                          1
#
#        is_transmission_MANUAL  is_transmission_AUTOMATED_MANUAL
# 2839                        1                                 0
# 7553                        0                                 0
# 10214                       0                                 0
# 7614                        0                                 0
# 7789                        0                                 0

# %%
y_train.head()
# Out:
# 2839       2000
# 7553     433550
# 10214     35315
# 7614      30145
# 7789      39900
# Name: MSRP, dtype: int64

# %%
x_train_mat = x_train.values
x_val_mat = x_val.values
x_test_mat = x_test.values

# %%
def train_linear_regression(X, y):
    # Add the 1 feature value for the bias term in our feature matrix
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    # Calculate XTX (Gram matrix)
    XTX = X.T.dot(X)
    # Calculate the inverse of the Gram matrix
    XTX_inv = np.linalg.inv(XTX)
    # Extract w
    w = XTX_inv.dot(X.T).dot(y)
    
    return w[0], w[1:]

# %%
w0, w = train_linear_regression(x_train_mat, y_train)
y_pred_val = w0 + x_val_mat.dot(w)

# %%
def rmse(y, y_pred):
    error = y_pred - y
    # Mean squared error (MSE)
    mse = (error ** 2).mean()
    # Return the root of the mean squared error
    return np.sqrt(mse)
